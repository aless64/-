# %% [markdown]
# <a href="https://colab.research.google.com/github/aless64/-/blob/Main/%F0%9D%96%98%F0%9D%96%86%F0%9D%96%91%F0%9D%96%86_%F0%9D%96%89%F0%9D%96%8A_%F0%9D%96%8E%F0%9D%96%93%F0%9D%96%8B%F0%9D%96%94%F0%9D%96%97%F0%9D%96%92%F0%9D%96%86%F0%9D%96%99%F0%9D%96%8E%F0%9D%96%88%F0%9D%96%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numeronumero_alunos = int(input("digite a quantidade de alunos:"))
numero_monitores = int(input("digite a quantidade de monitores:"))
resporespostasta_positiva = "pode ir"
resposta_negativa = "não pode ir"

if numero_alunos + numero_monitores <=50:
 print(resposta_positiva)

else:
 print(resposta_negativa)
# Out:
# digite a quantidade de alunos:10
# digite a quantidade de monitores:40
# pode ir
